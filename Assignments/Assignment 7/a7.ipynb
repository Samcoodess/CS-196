# %%
# !pip install kivy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kivy
#   Downloading Kivy-2.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 35.6 MB/s eta 0:00:00
# Collecting Kivy-Garden>=0.1.4
#   Downloading Kivy_Garden-0.1.5-py3-none-any.whl (4.6 kB)
# Requirement already satisfied: docutils in /usr/local/lib/python3.9/dist-packages (from kivy) (0.16)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from kivy) (2.14.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from Kivy-Garden>=0.1.4->kivy) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy) (2.0.12)
# Installing collected packages: Kivy-Garden, kivy
# Successfully installed Kivy-Garden-0.1.5 kivy-2.1.0

# %%
from kivy.app import App
from kivy.uix.label import Label
from kivy.core.window import Window

Window.size = (400,300)

class MyApp(App):
  def build(self):

    self.title = 'my first app'
    return Label(text='Hello')
MyApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in /root/.kivy/logs/kivy_23-03-31_2.txt
# INFO:kivy:Logger: Record log in /root/.kivy/logs/kivy_23-03-31_2.txt
# [INFO   ] [Kivy        ] v2.1.0
# INFO:kivy:Kivy: v2.1.0
# [INFO   ] [Kivy        ] Installed at "/usr/local/lib/python3.9/dist-packages/kivy/__init__.py"
# INFO:kivy:Kivy: Installed at "/usr/local/lib/python3.9/dist-packages/kivy/__init__.py"
# [INFO   ] [Python      ] v3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# INFO:kivy:Python: v3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# [INFO   ] [Python      ] Interpreter at "/usr/bin/python3"
# INFO:kivy:Python: Interpreter at "/usr/bin/python3"
# [INFO   ] [Logger      ] Purge log fired. Processing...
# INFO:kivy:Logger: Purge log fired. Processing...
# [INFO   ] [Logger      ] Purge finished!
# INFO:kivy:Logger: Purge finished!
# [INFO   ] [Factory     ] 189 symbols loaded
# INFO:kivy:Factory: 189 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# INFO:kivy:Image: Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# INFO:kivy:Text: Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2
# INFO:kivy:Window: Provider: sdl2
# [INFO   ] [Window      ] Provider: x11(['window_sdl2'] ignored)
# INFO:kivy:Window: Provider: x11(['window_sdl2'] ignored)
